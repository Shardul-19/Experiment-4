# %%
#Shardul Rasal
#25070123155

# %%
thisset={"apple","banana","cherry",}
print(thisset)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
thisset={"apple","banana","cherry",}
print(thisset[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1828713404.py in <cell line: 0>()
#       1 thisset={"apple","banana","cherry",}
# ----> 2 print(thisset[1])
#
# TypeError: 'set' object is not subscriptable

# %%
thisset={"apple","banana","cherry","apple"}
print(thisset)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
thisset={"apple","banana","cherry",True,1,2}
print(thisset)
# Out:
# {True, 2, 'banana', 'apple', 'cherry'}

# %%
thisset={"apple","banana","cherry","apple"}
print("banana" in thisset)
print("Grapes" in thisset)
# Out:
# True
# False

# %%
thisset={"apple","banana","cherry"}
thisset.add("orange")
print(thisset)
# Out:
# {'orange', 'banana', 'apple', 'cherry'}

# %%
thisset={"apple","banana","cherry"}
thisset.add(2)
print(thisset)
# Out:
# {'banana', 'apple', 2, 'cherry'}

# %%
thisset={"apple","banana","cherry"}
thisset.remove("banana")
print(thisset)
# Out:
# {'apple', 'cherry'}

# %%
# Set Operation
A = {1,2,3,4}
B = {3,4,5,6}
print("union:", A|B)
print("intersection:", A&B)
print("Difference1:", A-B)
print("Difference2:", B-A)
print("symmetric difference:", A^B)
# Out:
# union: {1, 2, 3, 4, 5, 6}
# intersection: {3, 4}
# Difference1: {1, 2}
# Difference2: {5, 6}
# symmetric difference: {1, 2, 5, 6}

# %%
# Frozenset
x = frozenset({"apple","banana","cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'banana', 'apple', 'cherry'})
# <class 'frozenset'>

# %%
studentlist={"a","b","c","d","b","c"}
studentlist = set(studentlist)
y = studentlist
print(y)
# Out:
# {'a', 'c', 'b', 'd'}

# %%
x = {"Maths","Physics","Chemistry"}
y = {"Biology","Physics","Chemistry"}
z= {"Maths","Biology","Chemistry"}
common_subjects = x & y & z
print(common_subjects)
# Out:
# {'Chemistry'}

# %%
cricket = {"Vishvam","Yuvraj","Niyant"}
football = {"Vishvam","Glen","Vrishin"}
print("students in one club are", cricket & football)
print("students in one club are", cricket ^ football)
# Out:
# students in one club are {'Vishvam'}
# students in one club are {'Vrishin', 'Glen', 'Niyant', 'Yuvraj'}

# %%
all_students = {"Vishvam","Khush","Harshit","Kshitij","Niyant","Yuvraj"}
present_students ={"Vishvam","Khush","Niyant" }
absent_students = all_students - present_students
print("Absent students", absent_students)
# Out:
# Absent students {'Kshitij', 'Yuvraj', 'Harshit'}

# %%
course = {"ETC101", "ETC102", "ETC103"}
course.discard("ETC102")
print("Updated Course", course)
# Out:
# Updated Course {'ETC101', 'ETC103'}
